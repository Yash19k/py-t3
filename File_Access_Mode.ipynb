# %%
f=open("test.txt","r")

# %%
# %%writefile demo.txt
# hello there
# Out:
# Writing demo.txt

# %%
print(f.read())
# Out:
# hello

# %%
print(f.read())

# %%
f.tell()
# Out:
# 5

# %%
f.seek(0)
# Out:
# 0

# %%
print(f.read())
# Out:
# hello

# %%
f.close()

# %%
f=open("test.txt","r+")

# %%
print(f.read())
# Out:
# hello

# %%
print(f.write("HI"))
# Out:
# 2

# %%
print(f.read())

# %%
f.seek(0)
# Out:
# 0

# %%
print(f.read())
# Out:
# HIlloHI

# %%
f.close()

# %%
f=open("test.txt","r+")
f.read()
# Out:
# 'HIlloHI\nWorld'

# %%
f=open("demo.txt","w")

# %%
f.write("hello\n")
f.write("hello")
# Out:
# 5

# %%
f.close()

# %% [markdown]
# with open("demo.txt","w") as f:
#     f.write("hello")
#     print(f.closed)
# print(f.closed)

# %%
with open("demo.txt","w+") as f:
    f.write("hello")
    f.seek(0)
    print(f.read())
# Out:
# hello

# %%
with open("demo.txt","a+") as f:
    f.write("hello")
    f.seek(0)
    f.write("Bye")
    print(f.read())

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
f=open("test.txt","r")
f1=open("demo.txt","w")
a=f.read()
f1.write(a.upper())
f1.close()
f.close()

# %%
with open("demo.txt","r") as f:
    print(f.read(-2))
# Out:
# hello

# %%
with open("demo.txt","r") as f:
    print(f.read(2,4))
    print(f.read(2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-4f181b0013ae> in <module>
#       1 with open("demo.txt","r") as f:
# ----> 2     print(f.read(2,4))
#       3     print(f.read(2))
#
# TypeError: read expected at most 1 argument, got 2

# %%
with open("demo.txt","r") as f:
    print(f.readline(7))
    print(f.readline(1))
# Out:
# hello
#
# f

# %%
for i in s:
    print(i)
# Out:
# f
#
# ss
#
# as
#
# dw
