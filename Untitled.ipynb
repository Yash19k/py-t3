# %%
lc=0
sp=0
wc=0
f=open("demo.txt","r+")
rl=f.readlines()
lc=len(rl)
f.seek(0)
b=f.read()
wc=b.split()
print("Total word count:",len(wc))
print("Total lines count:",lc)
y=len(b)-b.count(" ")-b.count("\n")
print("Total characters count:",y)
sp=b.count(" ")
print("Total space count:",sp)
# Out:
# Total word count: 5
# Total lines count: 2
# Total characters count: 19
# Total space count: 3

# %%
a=input("Enter File Name : ")
r=int(input("Enter Range : "))
with open(a,"r") as f:
    flag=True
    while(flag):
        for i in range(r):
            x=f.readline()
            if(x!=""):
                print(x,end="")
            else:
                break
        b=input("Enter : ")
        if(b=="q" or x==""):
            flag=False
# Out:
# Enter File Name : demo.txt
# Enter Range : 7
# 1-hello world
# 2-how are you
# 3-hello world
# 4-how are you
# 5-hello world
# 6-how are you
# 7-hello world
# Enter :
# 8-how are you
# 9-hello world
# 10-how are you
# 11-hello world
# 12-how are you

# %%
f=open("demo.txt","r")
print(id(f))
print(f)
for i in f:
    print(i)
# Out:
# 1839426089440
# <_io.TextIOWrapper name='demo.txt' mode='r' encoding='cp1252'>
# 1-hello world
#
# 2-how are you
#
# 3-hello world
#
# 4-how are you
#
# 5-hello world
#
# 6-how are you
#
# 7-hello world
#
# 8-how are you
#
# 9-hello world
#
# 10-how are you
#
# 11-hello world
#
# 12-how are you

# %%
f1=open("test.txt")
f2=open("demo.txt","r")
a=f1.readlines()
b=f2.readlines()
for i in b :
    for j in i:
        x1=j.split()
for i in a :
    for j in i:
        x2=j.split()
while
# Out:
# ['1']
# ['-']
# ['h']
# ['e']
# ['l']
# ['l']
# ['o']
# []
# ['w']
# ['o']
# ['r']
# ['l']
# ['d']
# []
# ['2']
# ['-']
# ['h']
# ['o']
# ['w']
# []
# ['a']
# ['r']
# ['e']
# []
# ['y']
# ['o']
# ['u']
# []
# ['3']
# ['-']
# ['h']
# ['e']
# ['l']
# ['l']
# ['o']
# []
# ['w']
# ['o']
# ['r']
# ['l']
# ['d']
# []
# ['4']
# ['-']
# ['h']
# ['o']
# ['w']
# []
# ['a']
# ['r']
# ['e']
# []
# ['y']
# ['o']
# ['u']
# []
# ['5']
# ['-']
# ['h']
# ['e']
# ['l']
# ['l']
# ['o']
# []
# ['w']
# ['o']
# ['r']
# ['l']
# ['d']
# []
# ['6']
# ['-']
# ['h']
# ['o']
# ['w']
# []
# ['a']
# ['r']
# ['e']
# []
# ['y']
# ['o']
# ['u']
# []
# ['7']
# ['-']
# ['h']
# ['e']
# ['l']
# ['l']
# ['o']
# []
# ['w']
# ['o']
# ['r']
# ['l']
# ['d']
# []
# ['8']
# ['-']
# ['h']
# ['o']
# ['w']
# []
# ['a']
# ['r']
# ['e']
# []
# ['y']
# ['o']
# ['u']
# []
# ['9']
# ['-']
# ['h']
# ['e']
# ['l']
# ['l']
# ['o']
# []
# ['w']
# ['o']
# ['r']
# ['l']
# ['d']
# []
# ['1']
# ['0']
# ['-']
# ['h']
# ['o']
# ['w']
# []
# ...

# %%
f1=open("test.txt")
f2=open("demo.txt","r")
a=f1.readlines()
b=f2.readlines()
r=0
w=0
for i,j in a,b:
    for l,m in i,j:
        print(i)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-03139f4013ae> in <module>
#       5 r=0
#       6 w=0
# ----> 7 for i,j in a,b:
#       8     for l,m in i,j:
#       9         print(i)
#
# ValueError: not enough values to unpack (expected 2, got 0)

# %%
f1=open("demo.txt")
a=f1.readlines()
f2=open("demo.txt","w+")
for i in a:
    print(a)
    for j in i:
        if(j!="#"):
            f2.write(j)
        else:
            f2.readline()
f2.close()
# Out:
# ['helo worls hdkd']
